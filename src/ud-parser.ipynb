# %% [markdown]
# ## Draft for processing UD treebanks - goal: Return question sentences from a select treebank
#
# The treebanks we will be exploring were chosen according to diversity in syntactic and morphological features of the language and the absolute quality rank of the treebank as reported by

# %%
# !pip install stanza conllu

# %%
import stanza
from stanza.utils.conll import CoNLL
import conllu

# %%
import os
from udapi.core.document import Document

path = os.path.expanduser('~/Research/qtype-eval/data/ud_data/UD_English-Atis/en_atis-ud-dev.conllu')


with open(path, 'r') as f:
    first_lines = f.readlines()[:5]
    print("First few lines:")
    print(''.join(first_lines))


doc = Document()
doc.load_conllu(path)

print(f"Number of sentences: {len(doc.bundles)}")
# Out:
# First few lines:
# # sent_id = 0001.dev
# # text = i would like the cheapest flight from pittsburgh to atlanta leaving april twenty fifth and returning may sixth
# 1	i	I	PRON	_	Case=Nom|Number=Sing|Person=1|PronType=Prs	3	nsubj	_	_
# 2	would	will	AUX	_	_	3	aux	_	_
# 3	like	like	VERB	_	VerbForm=Inf	0	root	_	_
#
# Number of sentences: 572

# %%
! cat ~/Research/qtype-eval/data/ud_data/UD_English-Atis/en_atis-ud-dev.conllu | udapy -T | head -n 40
# Out:
# 2025-02-09 15:48:13,212 [   INFO] execute - No reader specified, using read.Conllu
# 2025-02-09 15:48:13,212 [   INFO] execute -  ---- ROUND ----
# 2025-02-09 15:48:13,212 [   INFO] execute - Executing block read.Conllu
# 2025-02-09 15:48:13,264 [   INFO] execute - Executing block write.TextModeTrees
# global.Entity = None
# loaded_from = -
# # sent_id = 0001.dev
# # text = i would like the cheapest flight from pittsburgh to atlanta leaving april twenty fifth and returning may sixth
# ─┮
#  │ ╭─╼ i PRON nsubj
#  │ ┢─╼ would AUX aux
#  ╰─┾ like VERB root
#    │ ╭─╼ the DET det
#    │ ┢─╼ cheapest ADJ amod
#    ╰─┾ flight NOUN obj
#      │ ╭─╼ from ADP case
#      ┡─┾ pittsburgh PROPN nmod
#      │ │ ╭─╼ to ADP case
#      │ ╰─┶ atlanta PROPN nmod
#      ╰─┮ leaving VERB acl:relcl
#        ┡─┮ april NOUN obl
#        │ ╰─┮ twenty NUM appos
#        │   ╰─╼ fifth ADJ amod
#        │ ╭─╼ and CCONJ cc
#        ╰─┾ returning VERB conj
#          ╰─┮ may NOUN obl
#            ╰─╼ sixth ADJ amod
#
# # sent_id = 0002.dev
# # text = i want a flight from memphis to seattle that arrives no later than 3 pm
# ─┮
#  │ ╭─╼ i PRON nsubj
#  ╰─┾ want VERB root
#    │ ╭─╼ a DET det
#    ╰─┾ flight NOUN obj
#      │ ╭─╼ from ADP case
#      ┡─┶ memphis PROPN nmod
#      │ ╭─╼ to ADP case
#      ┡─┶ seattle PROPN nmod
#      │ ╭─╼ that ADP nsubj
#      ╰─┾ arrives VERB acl:relcl
#        │ ╭─╼ no DET det
#        ╰─┾ later ADV obl
#          │ ╭─╼ than ADP case

# %%
import udapi
import os

path = os.path.expanduser('~/Research/qtype-eval/data/ud_data/UD_English-Atis/en_atis-ud-dev.conllu')
doc = udapi.Document(path)
doc[10].draw() # [n] = sent_id
# Out:
# # sent_id = 0011.dev
# # text = i need information for ground transportation denver colorado
# ─┮
#  │ ╭─╼ i PRON nsubj
#  ╰─┾ need VERB root
#    ╰─┮ information NOUN obj
#      │ ╭─╼ for ADP case
#      │ ┢─╼ ground NOUN compound
#      ╰─┾ transportation NOUN nmod
#        ╰─┮ denver PROPN list
#          ╰─╼ colorado PROPN appos

# %%
doc[10].draw(layout="align", attributes="ord,form,feats")
# Out:
# # sent_id = 0011.dev
# # text = i need information for ground transportation denver colorado
# ─┮
#  │ ╭─╼       1 i              Case=Nom|Number=Sing|Person=1|PronType=Prs
#  ╰─┾         2 need           Mood=Ind|Tense=Pres|VerbForm=Fin
#    ╰─┮       3 information    Number=Sing
#      │ ╭─╼   4 for            _
#      │ ┢─╼   5 ground         Number=Sing
#      ╰─┾     6 transportation Number=Sing
#        ╰─┮   7 denver         Number=Sing
#          ╰─╼ 8 colorado       Number=Sing

# %% [markdown]
# #### Configuring the question filtering process
# 1. create files where questions will live, make a file per data set split
# 2. think of how to configure the "filter", what logic should we use for finding questions in each treebank, can we use a universal filter or do we need language specific filters, are datasets homogenous in which feats they contain

# %%
from udapi.core.block import Block
from udapi.core.document import Document
from udapi.block.write.conllu import Conllu
import os

#configure input and output files, make sure to respect split names

input_file = os.path.expanduser('~/Research/qtype-eval/data/ud_data/UD_English-Atis/en_atis-ud-dev.conllu')

output_file = os.path.expanduser('/home/robin/Research/qtype-eval/data/filtered_data/en-atis-questions/en_atis-questions.dev.conllu')


def question(tree):

    # first pass at filtering anything but questions would look at the presence of '?'

    for node in tree.descendants:
        if node.form == '?':
            return True

    # more elaborate way would be to look for specific question words at specific places in the tree
    #     
    interrogatives = {'how', 'what', 'which', 'when', 'where', 'who', 'why', 'whose', 'whom', 'whether', 'could', 'would', 'should'}

    if tree.descendants:
        first_node = tree.descendants[0] # look at the first word in the sentence
        print(f"First word: {first_node.form}, UPOS: {first_node.upos}, Features: {first_node.feats}")
        if first_node.form.lower() in interrogatives:
            print("Found interrogative word at start!")
            return True


doc = Document(input_file)
filtered_doc = Document()

questions_found = 0 # counter for keeping track of how many question we add to our new file

# main loop to filter our file

for tree in doc.trees:
    if question(tree):
        questions_found += 1
        bundle = filtered_doc.create_bundle()
        bundle.add_tree(tree)

print(f"\nTotal questions found in this file: {questions_found}")

filtered_doc.store_conllu(output_file)
print(f"\nExtracted questions and saved to '{output_file}'")
# Out:
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: could, UPOS: AUX, Features: _
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: display, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: and, UPOS: CCONJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: on, UPOS: ADP, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: can, UPOS: AUX, Features: _
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: explain, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: please, UPOS: INTJ, Features: _
# First word: tell, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: all, UPOS: DET, Features: PronType=Art
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: rental, UPOS: ADJ, Features: Degree=Pos
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: to, UPOS: ADP, Features: _
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: from, UPOS: ADP, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: all, UPOS: DET, Features: PronType=Art
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: ground, UPOS: NOUN, Features: Number=Sing
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: tell, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: airports, UPOS: NOUN, Features: Number=Plur
# First word: where, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: is, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: between, UPOS: ADP, Features: _
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: kansas, UPOS: PROPN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: can, UPOS: AUX, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: let, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: is, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: on, UPOS: ADP, Features: _
# First word: please, UPOS: INTJ, Features: _
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: tell, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: is, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: ground, UPOS: NOUN, Features: Number=Sing
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: on, UPOS: ADP, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: could, UPOS: AUX, Features: _
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: oakland, UPOS: PROPN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: can, UPOS: AUX, Features: _
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: all, UPOS: DET, Features: PronType=Art
# First word: is, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: on, UPOS: ADP, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: on, UPOS: ADP, Features: _
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: is, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: please, UPOS: INTJ, Features: _
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: cleveland, UPOS: PROPN, Features: Number=Sing
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: kansas, UPOS: PROPN, Features: Number=Sing
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: on, UPOS: ADP, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: on, UPOS: ADP, Features: _
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: okay, UPOS: INTJ, Features: _
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: okay, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: does, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: nonstop, UPOS: NOUN, Features: Number=Sing
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: are, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: on, UPOS: ADP, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: round, UPOS: NOUN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: july, UPOS: NOUN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: ground, UPOS: NOUN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: does, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: tell, UPOS: VERB, Features: VerbForm=Inf
# First word: ground, UPOS: NOUN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: does, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: hello, UPOS: INTJ, Features: _
# First word: okay, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: us, UPOS: PROPN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: can, UPOS: AUX, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: okay, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: can, UPOS: AUX, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: can, UPOS: AUX, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: cheapest, UPOS: ADJ, Features: Degree=Sup
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: now, UPOS: ADV, Features: Degree=Pos
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: nashville, UPOS: PROPN, Features: Number=Sing
# First word: all, UPOS: DET, Features: PronType=Art
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: now, UPOS: ADV, Features: Degree=Pos
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: and, UPOS: CCONJ, Features: _
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: tell, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: is, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: where, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: can, UPOS: AUX, Features: _
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: afternoon, UPOS: NOUN, Features: Number=Sing
# First word: can, UPOS: AUX, Features: _
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: early, UPOS: ADJ, Features: Degree=Pos
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: evening, UPOS: NOUN, Features: Number=Sing
# First word: baltimore, UPOS: PROPN, Features: Number=Sing
# First word: information, UPOS: NOUN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: san, UPOS: PROPN, Features: Number=Sing
# First word: san, UPOS: PROPN, Features: Number=Sing
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: from, UPOS: ADP, Features: _
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: san, UPOS: PROPN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: does, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: american, UPOS: PROPN, Features: Number=Sing
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: pittsburgh, UPOS: PROPN, Features: Number=Sing
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: from, UPOS: ADP, Features: _
# First word: denver, UPOS: PROPN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: boston, UPOS: PROPN, Features: Number=Sing
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: all, UPOS: DET, Features: PronType=Art
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: denver, UPOS: PROPN, Features: Number=Sing
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: philadelphia, UPOS: PROPN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: all, UPOS: DET, Features: PronType=Art
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: from, UPOS: ADP, Features: _
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: now, UPOS: ADV, Features: Degree=Pos
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: newark, UPOS: PROPN, Features: Number=Sing
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: could, UPOS: AUX, Features: _
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: okay, UPOS: INTJ, Features: _
# First word: can, UPOS: AUX, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: is, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: also, UPOS: ADV, Features: Degree=Pos
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Total questions found in this file: 169
#
# Extracted questions and saved to '/home/robin/Research/qtype-eval/data/filtered_data/en-atis-questions/en_atis-questions.dev.conllu'

# %% [markdown]
# ### Now we can continue with other splits for the same bank
#
# 1. create separate files for dev/train/test splits
# 2. select the correct input and output file
# 3. repeat for all splits
# 4. repeat for all tree banks

# %%
from udapi.core.block import Block
from udapi.core.document import Document
from udapi.block.write.conllu import Conllu
import os

#configure input and output files, make sure to respect split names

input_file = os.path.expanduser('~/Research/qtype-eval/data/ud_data/UD_English-Atis/en_atis-ud-test.conllu')

output_file = os.path.expanduser('/home/robin/Research/qtype-eval/data/filtered_data/en-atis-questions/en_atis-questions.test.conllu')


def question(tree):

    # first pass at filtering anything but questions would look at the presence of '?'

    for node in tree.descendants:
        if node.form == '?':
            return True

    # more elaborate way would be to look for specific question words at specific places in the tree
    #     
    interrogatives = {'how', 'what', 'which', 'when', 'where', 'who', 'why', 'whose', 'whom', 'whether', 'could', 'would', 'should'}

    if tree.descendants:
        first_node = tree.descendants[0] # look at the first word in the sentence
        print(f"First word: {first_node.form}, UPOS: {first_node.upos}, Features: {first_node.feats}")
        if first_node.form.lower() in interrogatives:
            print("Found interrogative word at start!")
            return True


doc = Document(input_file)
filtered_doc = Document()

questions_found = 0 # counter for keeping track of how many question we add to our new file

# main loop to filter our file

for tree in doc.trees:
    if question(tree):
        questions_found += 1
        bundle = filtered_doc.create_bundle()
        bundle.add_tree(tree)

print(f"\nTotal questions found in this file: {questions_found}")

filtered_doc.store_conllu(output_file)
print(f"\nExtracted questions and saved to '{output_file}'")
# Out:
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: explain, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: in, UPOS: ADP, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: please, UPOS: INTJ, Features: _
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: now, UPOS: ADV, Features: Degree=Pos
# First word: from, UPOS: ADP, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: which, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: get, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: on, UPOS: ADP, Features: _
# First word: can, UPOS: AUX, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: information, UPOS: NOUN, Features: Number=Sing
# First word: please, UPOS: INTJ, Features: _
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: houston, UPOS: PROPN, Features: Number=Sing
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: where, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: round, UPOS: NOUN, Features: Number=Sing
# First word: round, UPOS: NOUN, Features: Number=Sing
# First word: all, UPOS: DET, Features: PronType=Art
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: baltimore, UPOS: PROPN, Features: Number=Sing
# First word: economy, UPOS: NOUN, Features: Number=Sing
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: can, UPOS: AUX, Features: _
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: nonstop, UPOS: NOUN, Features: Number=Sing
# First word: please, UPOS: INTJ, Features: _
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: and, UPOS: CCONJ, Features: _
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: when, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: in, UPOS: ADP, Features: _
# First word: is, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: may, UPOS: AUX, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: please, UPOS: INTJ, Features: _
# First word: can, UPOS: AUX, Features: _
# First word: of, UPOS: ADP, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: great, UPOS: ADJ, Features: Degree=Pos
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: ground, UPOS: NOUN, Features: Number=Sing
# First word: ground, UPOS: NOUN, Features: Number=Sing
# First word: tell, UPOS: VERB, Features: VerbForm=Inf
# First word: now, UPOS: ADV, Features: Degree=Pos
# First word: saturday, UPOS: NOUN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: could, UPOS: AUX, Features: _
# Found interrogative word at start!
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: a, UPOS: DET, Features: PronType=Art
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: morning, UPOS: NOUN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: could, UPOS: AUX, Features: _
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: does, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: does, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: repeating, UPOS: VERB, Features: Tense=Pres|VerbForm=Part
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: could, UPOS: AUX, Features: _
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: and, UPOS: CCONJ, Features: _
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: nonstop, UPOS: NOUN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: tell, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: may, UPOS: AUX, Features: _
# First word: please, UPOS: INTJ, Features: _
# First word: on, UPOS: ADP, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: cheapest, UPOS: ADJ, Features: Degree=Sup
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: define, UPOS: VERB, Features: VerbForm=Inf
# First word: code, UPOS: NOUN, Features: Number=Sing
# First word: from, UPOS: ADP, Features: _
# First word: airline, UPOS: NOUN, Features: Number=Sing
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: all, UPOS: DET, Features: PronType=Art
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: cleveland, UPOS: PROPN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: does, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: please, UPOS: INTJ, Features: _
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: nonstop, UPOS: NOUN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: first, UPOS: ADJ, Features: Degree=Pos|NumType=Ord
# First word: first, UPOS: ADJ, Features: Degree=Pos|NumType=Ord
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: first, UPOS: ADJ, Features: Degree=Pos|NumType=Ord
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: first, UPOS: ADJ, Features: Degree=Pos|NumType=Ord
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: ground, UPOS: NOUN, Features: Number=Sing
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: ground, UPOS: NOUN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: can, UPOS: AUX, Features: _
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: all, UPOS: DET, Features: PronType=Art
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: can, UPOS: AUX, Features: _
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: dallas, UPOS: PROPN, Features: Number=Sing
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: a, UPOS: DET, Features: PronType=Art
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: can, UPOS: AUX, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: shortest, UPOS: ADJ, Features: Degree=Sup
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: can, UPOS: AUX, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: lowest, UPOS: ADJ, Features: Degree=Sup
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: okay, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: all, UPOS: DET, Features: PronType=Art
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: hi, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: now, UPOS: ADV, Features: Degree=Pos
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: okay, UPOS: INTJ, Features: _
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: on, UPOS: ADP, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: get, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: continental, UPOS: PROPN, Features: Number=Sing
# First word: does, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: american, UPOS: PROPN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: on, UPOS: ADP, Features: _
# First word: st., UPOS: PROPN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: now, UPOS: ADV, Features: Degree=Pos
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: from, UPOS: ADP, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: morning, UPOS: NOUN, Features: Number=Sing
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: am, UPOS: NOUN, Features: Number=Sing
# First word: tampa, UPOS: PROPN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: from, UPOS: ADP, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: st., UPOS: PROPN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: from, UPOS: ADP, Features: _
# First word: sunday, UPOS: NOUN, Features: Number=Sing
# First word: please, UPOS: INTJ, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: only, UPOS: ADV, Features: Degree=Pos
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: all, UPOS: DET, Features: PronType=Art
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: when, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: please, UPOS: INTJ, Features: _
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: baltimore, UPOS: PROPN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: interested, UPOS: VERB, Features: Tense=Past|VerbForm=Part
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: tell, UPOS: VERB, Features: VerbForm=Inf
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: the, UPOS: DET, Features: PronType=Art
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: information, UPOS: NOUN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: tell, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: now, UPOS: ADV, Features: Degree=Pos
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: get, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: no, UPOS: DET, Features: PronType=Art
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: tell, UPOS: VERB, Features: VerbForm=Inf
# First word: oakland, UPOS: PROPN, Features: Number=Sing
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: atlanta, UPOS: PROPN, Features: Number=Sing
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: also, UPOS: ADV, Features: Degree=Pos
#
# Total questions found in this file: 193
#
# Extracted questions and saved to '/home/robin/Research/qtype-eval/data/filtered_data/en-atis-questions/en_atis-questions.test.conllu'

# %%
from udapi.core.block import Block
from udapi.core.document import Document
from udapi.block.write.conllu import Conllu
import os

#configure input and output files, make sure to respect split names

input_file = os.path.expanduser('~/Research/qtype-eval/data/ud_data/UD_English-Atis/en_atis-ud-train.conllu')

output_file = os.path.expanduser('/home/robin/Research/qtype-eval/data/filtered_data/en-atis-questions/en_atis-questions.train.conllu')


def question(tree):

    # first pass at filtering anything but questions would look at the presence of '?'

    for node in tree.descendants:
        if node.form == '?':
            return True

    # more elaborate way would be to look for specific question words at specific places in the tree
    #     
    interrogatives = {'how', 'what', 'which', 'when', 'where', 'who', 'why', 'whose', 'whom', 'whether', 'could', 'would', 'should'}

    if tree.descendants:
        first_node = tree.descendants[0] # look at the first word in the sentence
        print(f"First word: {first_node.form}, UPOS: {first_node.upos}, Features: {first_node.feats}")
        if first_node.form.lower() in interrogatives:
            print("Found interrogative word at start!")
            return True


doc = Document(input_file)
filtered_doc = Document()

questions_found = 0 # counter for keeping track of how many question we add to our new file

# main loop to filter our file

for tree in doc.trees:
    if question(tree):
        questions_found += 1
        bundle = filtered_doc.create_bundle()
        bundle.add_tree(tree)

print(f"\nTotal questions found in this file: {questions_found}")

filtered_doc.store_conllu(output_file)
print(f"\nExtracted questions and saved to '{output_file}'")
# Out:
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: now, UPOS: ADV, Features: Degree=Pos
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: now, UPOS: ADV, Features: Degree=Pos
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: actually, UPOS: ADV, Features: Degree=Pos
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: okay, UPOS: INTJ, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: rental, UPOS: PROPN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: fine, UPOS: ADJ, Features: Degree=Pos
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: can, UPOS: AUX, Features: _
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: all, UPOS: DET, Features: PronType=Art
# First word: all, UPOS: DET, Features: PronType=Art
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: all, UPOS: DET, Features: PronType=Art
# First word: list, UPOS: NOUN, Features: Number=Sing
# First word: display, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: are, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: are, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: coach, UPOS: NOUN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: all, UPOS: DET, Features: PronType=Art
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: explain, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: explain, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: is, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: philadelphia, UPOS: PROPN, Features: Number=Sing
# First word: is, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: wednesday, UPOS: NOUN, Features: Number=Sing
# First word: tell, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: tell, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: sfo, UPOS: PROPN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: please, UPOS: INTJ, Features: _
# First word: may, UPOS: AUX, Features: _
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: can, UPOS: AUX, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: rental, UPOS: PROPN, Features: Number=Sing
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: can, UPOS: AUX, Features: _
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: can, UPOS: AUX, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: explain, UPOS: VERB, Features: VerbForm=Inf
# First word: explain, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: the, UPOS: DET, Features: PronType=Art
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: all, UPOS: DET, Features: PronType=Art
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: could, UPOS: AUX, Features: _
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: does, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: where, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: where, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: where, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: please, UPOS: INTJ, Features: _
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: on, UPOS: ADP, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: us, UPOS: PROPN, Features: Number=Sing
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: all, UPOS: DET, Features: PronType=Art
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: please, UPOS: INTJ, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: all, UPOS: DET, Features: PronType=Art
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: all, UPOS: DET, Features: PronType=Art
# First word: all, UPOS: DET, Features: PronType=Art
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: first, UPOS: ADJ, Features: Degree=Pos|NumType=Ord
# First word: again, UPOS: ADV, Features: Degree=Pos
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: does, UPOS: AUX, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: tell, UPOS: VERB, Features: VerbForm=Inf
# First word: airports, UPOS: NOUN, Features: Number=Plur
# First word: please, UPOS: INTJ, Features: _
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: tell, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: names, UPOS: NOUN, Features: Number=Plur
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: describe, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: instead, UPOS: ADV, Features: Degree=Pos
# First word: of, UPOS: ADP, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: and, UPOS: CCONJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: round, UPOS: NOUN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: round, UPOS: NOUN, Features: Number=Sing
# First word: round, UPOS: NOUN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: round, UPOS: NOUN, Features: Number=Sing
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: round, UPOS: NOUN, Features: Number=Sing
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: all, UPOS: DET, Features: PronType=Art
# First word: round, UPOS: NOUN, Features: Number=Sing
# First word: round, UPOS: NOUN, Features: Number=Sing
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: round, UPOS: NOUN, Features: Number=Sing
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: all, UPOS: DET, Features: PronType=Art
# First word: round, UPOS: NOUN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: can, UPOS: AUX, Features: _
# First word: can, UPOS: AUX, Features: _
# First word: can, UPOS: AUX, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: okay, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: las, UPOS: PROPN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: pittsburgh, UPOS: PROPN, Features: Number=Sing
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: okay, UPOS: INTJ, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: yes, UPOS: INTJ, Features: _
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: yes, UPOS: INTJ, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: please, UPOS: INTJ, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: then, UPOS: ADV, Features: Degree=Pos
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: on, UPOS: ADP, Features: _
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: okay, UPOS: INTJ, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: okay, UPOS: INTJ, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: okay, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: on, UPOS: ADP, Features: _
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: thank, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: could, UPOS: AUX, Features: _
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: newark, UPOS: PROPN, Features: Number=Sing
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: daily, UPOS: ADJ, Features: Degree=Pos
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: is, UPOS: VERB, Features: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: please, UPOS: INTJ, Features: _
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: sure, UPOS: ADJ, Features: Degree=Pos
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: please, UPOS: INTJ, Features: _
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: okay, UPOS: INTJ, Features: _
# First word: please, UPOS: INTJ, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# ...
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: could, UPOS: AUX, Features: _
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: looking, UPOS: VERB, Features: Tense=Pres|VerbForm=Part
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: all, UPOS: DET, Features: PronType=Art
# First word: let, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: okay, UPOS: INTJ, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: can, UPOS: AUX, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: can, UPOS: AUX, Features: _
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: could, UPOS: AUX, Features: _
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: chicago, UPOS: PROPN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: from, UPOS: ADP, Features: _
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: find, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: now, UPOS: ADV, Features: Degree=Pos
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: are, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: now, UPOS: ADV, Features: Degree=Pos
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: could, UPOS: AUX, Features: _
# Found interrogative word at start!
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: give, UPOS: VERB, Features: VerbForm=Inf
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: please, UPOS: INTJ, Features: _
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: please, UPOS: INTJ, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: phoenix, UPOS: PROPN, Features: Number=Sing
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: how, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: can, UPOS: AUX, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: can, UPOS: AUX, Features: _
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: when, UPOS: ADV, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: baltimore, UPOS: PROPN, Features: Number=Sing
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: need, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: information, UPOS: NOUN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: could, UPOS: AUX, Features: _
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: do, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: sure, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: are, UPOS: AUX, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: can, UPOS: AUX, Features: _
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: denver, UPOS: PROPN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: minneapolis, UPOS: PROPN, Features: Number=Sing
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: all, UPOS: DET, Features: PronType=Art
# First word: all, UPOS: DET, Features: PronType=Art
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: hello, UPOS: INTJ, Features: _
# First word: now, UPOS: ADV, Features: Degree=Pos
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: which, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: information, UPOS: NOUN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: could, UPOS: AUX, Features: _
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: flight, UPOS: NOUN, Features: Number=Sing
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: list, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: flights, UPOS: NOUN, Features: Number=Plur
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: are, UPOS: VERB, Features: Mood=Ind|Tense=Pres|VerbForm=Fin
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: PRON, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: show, UPOS: VERB, Features: VerbForm=Inf
# First word: i, UPOS: PRON, Features: Case=Nom|Number=Sing|Person=1|PronType=Prs
# First word: what, UPOS: DET, Features: PronType=Int,Rel
# Found interrogative word at start!
# First word: please, UPOS: INTJ, Features: _
# First word: show, UPOS: VERB, Features: VerbForm=Inf
#
# Total questions found in this file: 1256
#
# Extracted questions and saved to '/home/robin/Research/qtype-eval/data/filtered_data/en-atis-questions/en_atis-questions.train.conllu'

# %% [markdown]
# After collecting data for the `UD_English-Atis` tree bank, we can move on to other treebanks, another interesting English tree bank is `UD_English-EWT`.

# %%
from udapi.core.block import Block
from udapi.core.document import Document
from udapi.block.write.conllu import Conllu
import os

#configure input and output files, make sure to respect split names

input_file = os.path.expanduser('~/Research/qtype-eval/data/ud_data/UD_English-EWT/en_ewt-ud-dev.conllu')
output_file = os.path.expanduser('~/Research/qtype-eval/data/filtered_data/en-ewt-questions/en_ewt-questions-dev.conllu')


def question(tree):

    # first pass at filtering anything but questions would look at the presence of '?'

    for node in tree.descendants:
        if node.form == '?':
            return True

    # more elaborate way would be to look for specific question words at specific places in the tree, EWT has annotated punctuation

    # interrogatives = {'how', 'what', 'which', 'when', 'where', 'who', 'why', 'whose', 'whom', 'whether', 'could', 'would', 'should'}

    #if tree.descendants:
    #    first_node = tree.descendants[0] # look at the first word in the sentence
    #    print(f"First word: {first_node.form}, UPOS: {first_node.upos}, Features: {first_node.feats}")
    #   if first_node.form.lower() in interrogatives:
    #        print("Found interrogative word at start!")
    #        return True
    


doc = Document(input_file)
filtered_doc = Document()

questions_found = 0 # counter for keeping track of how many question we add to our new file

# main loop to filter our file

for tree in doc.trees:
    if question(tree):
        questions_found += 1
        bundle = filtered_doc.create_bundle()
        bundle.add_tree(tree)

print(f"\nTotal questions found in this file: {questions_found}")

filtered_doc.store_conllu(output_file)
print(f"\nExtracted questions and saved to '{output_file}'")
# Out:
# Total questions found in this file: 163
#
# Extracted questions and saved to '/home/robin/Research/qtype-eval/data/filtered_data/en-ewt-questions/en_ewt-questions-dev.conllu'

# %%
from udapi.core.block import Block
from udapi.core.document import Document
from udapi.block.write.conllu import Conllu
import os

#configure input and output files, make sure to respect split names

input_file = os.path.expanduser('~/Research/qtype-eval/data/ud_data/UD_English-EWT/en_ewt-ud-test.conllu')

output_file = os.path.expanduser('~/Research/qtype-eval/data/filtered_data/en-ewt-questions/en_ewt-questions-test.conllu')


def question(tree):

    # first pass at filtering anything but questions would look at the presence of '?'

    for node in tree.descendants:
        if node.form == '?':
            return True

    # more elaborate way would be to look for specific question words at specific places in the tree, EWT has annotated punctuation

    # interrogatives = {'how', 'what', 'which', 'when', 'where', 'who', 'why', 'whose', 'whom', 'whether', 'could', 'would', 'should'}

    #if tree.descendants:
    #    first_node = tree.descendants[0] # look at the first word in the sentence
    #    print(f"First word: {first_node.form}, UPOS: {first_node.upos}, Features: {first_node.feats}")
    #   if first_node.form.lower() in interrogatives:
    #        print("Found interrogative word at start!")
    #        return True
    


doc = Document(input_file)
filtered_doc = Document()

questions_found = 0 # counter for keeping track of how many question we add to our new file

# main loop to filter our file

for tree in doc.trees:
    if question(tree):
        questions_found += 1
        bundle = filtered_doc.create_bundle()
        bundle.add_tree(tree)

print(f"\nTotal questions found in this file: {questions_found}")

filtered_doc.store_conllu(output_file)
print(f"\nExtracted questions and saved to '{output_file}'")
# Out:
# Total questions found in this file: 166
#
# Extracted questions and saved to '/home/robin/Research/qtype-eval/data/filtered_data/en-ewt-questions/en_ewt-questions-test.conllu'

# %%
from udapi.core.block import Block
from udapi.core.document import Document
from udapi.block.write.conllu import Conllu
import os

#configure input and output files, make sure to respect split names

input_file = os.path.expanduser('~/Research/qtype-eval/data/ud_data/UD_English-EWT/en_ewt-ud-train.conllu')

output_file = os.path.expanduser('~/Research/qtype-eval/data/filtered_data/en-ewt-questions/en_ewt-questions-train.conllu')


def question(tree):

    # first pass at filtering anything but questions would look at the presence of '?'

    for node in tree.descendants:
        if node.form == '?':
            return True

    # more elaborate way would be to look for specific question words at specific places in the tree, EWT has annotated punctuation

    # interrogatives = {'how', 'what', 'which', 'when', 'where', 'who', 'why', 'whose', 'whom', 'whether', 'could', 'would', 'should'}

    #if tree.descendants:
    #    first_node = tree.descendants[0] # look at the first word in the sentence
    #    print(f"First word: {first_node.form}, UPOS: {first_node.upos}, Features: {first_node.feats}")
    #   if first_node.form.lower() in interrogatives:
    #        print("Found interrogative word at start!")
    #        return True
    


doc = Document(input_file)
filtered_doc = Document()

questions_found = 0 # counter for keeping track of how many question we add to our new file

# main loop to filter our file

for tree in doc.trees:
    if question(tree):
        questions_found += 1
        bundle = filtered_doc.create_bundle()
        bundle.add_tree(tree)

print(f"\nTotal questions found in this file: {questions_found}")

filtered_doc.store_conllu(output_file)
print(f"\nExtracted questions and saved to '{output_file}'")
# Out:
# Total questions found in this file: 754
#
# Extracted questions and saved to '/home/robin/Research/qtype-eval/data/filtered_data/en-ewt-questions/en_ewt-questions-train.conllu'

# %% [markdown]
# ## Cross lingual question filter
# After collecting some .conllu files containing English questions we filtered from source English tree banks, we can move on to configuring question filter strategies for lanuages other than English. For example, we can try to come up with a similar strategy for filtering questions in Japanese from `UD_Japanese-GSD`

# %% [markdown]
# from udapi.core.block import Block
# from udapi.core.document import Document
# from udapi.block.write.conllu import Conllu
# import os
#
# #configure input and output files, make sure to respect split names
#
# input_file = os.path.expanduser('~/Research/qtype-eval/data/ud_data/UD_Japanese-GSD/ja_gsd-ud-dev.conllu')
#
# output_file = os.path.expanduser('~/Research/qtype-eval/data/filtered_data/ja-gsd-questions/ja-gsd-questions-dev.conllu')
#
#
# def question(tree):
#
#     # add question logic for japanese
#
#
# doc = Document(input_file)
# filtered_doc = Document()
#
# questions_found = 0 # counter for keeping track of how many question we add to our new file
#
# # main loop to filter our file
#
# for tree in doc.trees:
#     if question(tree):
#         questions_found += 1
#         bundle = filtered_doc.create_bundle()
#         bundle.add_tree(tree)
#
# print(f"\nTotal questions found in this file: {questions_found}")
#
# filtered_doc.store_conllu(output_file)
# print(f"\nExtracted questions and saved to '{output_file}'")

# %% [markdown]
# ## Syntax and Morphology
#
# Now that we have some questions, we can start by taking a look at how UD data stores the labels we might be interested in.

# %%
file = os.path.expanduser('~/Research/qtype-eval/data/filtered_data/en-ewt-questions/en_ewt-questions-train.conllu')

doc = udapi.Document(file)

doc[69].draw()

doc[69].draw(layout="align", attributes="ord,form,feats")
# Out:
# # sent_id = weblog-blogspot.com_dakbangla_20050311135387_ENG_20050311_135387-0216
# # text = What mosques exactly did they visit and who did they meet?
# ─┮
#  │   ╭─╼ What DET det
#  │ ╭─┾ mosques NOUN obj
#  │ │ ╰─╼ exactly ADV advmod
#  │ ┢─╼ did AUX aux
#  │ ┢─╼ they PRON nsubj
#  ╰─┾ visit VERB root
#    │ ╭─╼ and CCONJ cc
#    │ ┢─╼ who PRON obj
#    │ ┢─╼ did AUX aux
#    │ ┢─╼ they PRON nsubj
#    ┡─┶ meet VERB conj
#    ╰─╼ ? PUNCT punct
#
# # sent_id = weblog-blogspot.com_dakbangla_20050311135387_ENG_20050311_135387-0216
# # text = What mosques exactly did they visit and who did they meet?
# ─┮
#  │   ╭─╼ 1  What    PronType=Int
#  │ ╭─┾   2  mosques Number=Plur
#  │ │ ╰─╼ 3  exactly _
#  │ ┢─╼   4  did     Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin
#  │ ┢─╼   5  they    Case=Nom|Number=Plur|Person=3|PronType=Prs
#  ╰─┾     6  visit   VerbForm=Inf
#    │ ╭─╼ 7  and     _
#    │ ┢─╼ 8  who     PronType=Int
#    │ ┢─╼ 9  did     Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin
#    │ ┢─╼ 10 they    Case=Nom|Number=Plur|Person=3|PronType=Prs
#    ┡─┶   11 meet    VerbForm=Inf
#    ╰─╼   12 ?       _

# %% [markdown]
# ## References
